# %%
import streamlit as st
import numpy as np
from PIL import Image
import time
from scipy.spatial.distance import cdist
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-fd1859faecef> in <cell line: 1>()
# ----> 1 import streamlit as st
#       2 import numpy as np
#       3 from PIL import Image
#       4 import time
#       5 from scipy.spatial.distance import cdist
#
# ModuleNotFoundError: No module named 'streamlit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
@st.cache_data
def read_data():
    all_vecs = np.load("all_vecs.npy")
    all_names = np.load("all_names.npy")
    return all_vecs , all_names
# Out:
# 2023-08-15 15:23:45.616 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
vecs , names = read_data()

_ , *fcol2 , _ = st.columns(3)

scol1 , scol2 = st.columns(2)
# Out:
# ---------------------------------------------------------------------------
# CacheStorageKeyNotFoundError              Traceback (most recent call last)
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\storage\in_memory_cache_storage_wrapper.py:87, in InMemoryCacheStorageWrapper.get(self, key)
#      86 try:
# ---> 87     entry_bytes = self._read_from_mem_cache(key)
#      88 except CacheStorageKeyNotFoundError:
#
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\storage\in_memory_cache_storage_wrapper.py:137, in InMemoryCacheStorageWrapper._read_from_mem_cache(self, key)
#     136 _LOGGER.debug("Memory cache MISS: %s", key)
# --> 137 raise CacheStorageKeyNotFoundError("Key not found in mem cache")
#
# CacheStorageKeyNotFoundError: Key not found in mem cache
#
# During handling of the above exception, another exception occurred:
#
# CacheStorageKeyNotFoundError              Traceback (most recent call last)
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\cache_data_api.py:634, in DataCache.read_result(self, key)
#     633 try:
# --> 634     pickled_entry = self.storage.get(key)
#     635 except CacheStorageKeyNotFoundError as e:
#
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\storage\in_memory_cache_storage_wrapper.py:89, in InMemoryCacheStorageWrapper.get(self, key)
#      88 except CacheStorageKeyNotFoundError:
# ---> 89     entry_bytes = self._persist_storage.get(key)
#      90     self._write_to_mem_cache(key, entry_bytes)
#
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\storage\dummy_cache_storage.py:48, in DummyCacheStorage.get(self, key)
#      44 """
#      45 Dummy gets the value for a given key,
#      46 always raises an CacheStorageKeyNotFoundError
#      47 """
# ---> 48 raise CacheStorageKeyNotFoundError("Key not found in dummy cache")
#
# CacheStorageKeyNotFoundError: Key not found in dummy cache
#
# The above exception was the direct cause of the following exception:
#
# CacheKeyNotFoundError                     Traceback (most recent call last)
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:263, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs)
#     262 try:
# --> 263     cached_result = cache.read_result(value_key)
#     264     return self._handle_cache_hit(cached_result)
#
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\cache_data_api.py:636, in DataCache.read_result(self, key)
#     635 except CacheStorageKeyNotFoundError as e:
# --> 636     raise CacheKeyNotFoundError(str(e)) from e
#     637 except CacheStorageError as e:
#
# CacheKeyNotFoundError: Key not found in dummy cache
#
# During handling of the above exception, another exception occurred:
#
# CacheStorageKeyNotFoundError              Traceback (most recent call last)
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\storage\in_memory_cache_storage_wrapper.py:87, in InMemoryCacheStorageWrapper.get(self, key)
#      86 try:
# ---> 87     entry_bytes = self._read_from_mem_cache(key)
#      88 except CacheStorageKeyNotFoundError:
#
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\storage\in_memory_cache_storage_wrapper.py:137, in InMemoryCacheStorageWrapper._read_from_mem_cache(self, key)
#     136 _LOGGER.debug("Memory cache MISS: %s", key)
# --> 137 raise CacheStorageKeyNotFoundError("Key not found in mem cache")
#
# CacheStorageKeyNotFoundError: Key not found in mem cache
#
# During handling of the above exception, another exception occurred:
#
# CacheStorageKeyNotFoundError              Traceback (most recent call last)
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\cache_data_api.py:634, in DataCache.read_result(self, key)
#     633 try:
# --> 634     pickled_entry = self.storage.get(key)
#     635 except CacheStorageKeyNotFoundError as e:
#
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\storage\in_memory_cache_storage_wrapper.py:89, in InMemoryCacheStorageWrapper.get(self, key)
#      88 except CacheStorageKeyNotFoundError:
# ---> 89     entry_bytes = self._persist_storage.get(key)
#      90     self._write_to_mem_cache(key, entry_bytes)
#
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\storage\dummy_cache_storage.py:48, in DummyCacheStorage.get(self, key)
#      44 """
#      45 Dummy gets the value for a given key,
#      46 always raises an CacheStorageKeyNotFoundError
#      47 """
# ---> 48 raise CacheStorageKeyNotFoundError("Key not found in dummy cache")
#
# CacheStorageKeyNotFoundError: Key not found in dummy cache
#
# The above exception was the direct cause of the following exception:
#
# CacheKeyNotFoundError                     Traceback (most recent call last)
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:311, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     310 try:
# --> 311     cached_result = cache.read_result(value_key)
#     312     # Another thread computed the value before us. Early exit!
#
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\cache_data_api.py:636, in DataCache.read_result(self, key)
#     635 except CacheStorageKeyNotFoundError as e:
# --> 636     raise CacheKeyNotFoundError(str(e)) from e
#     637 except CacheStorageError as e:
#
# CacheKeyNotFoundError: Key not found in dummy cache
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 vecs , names = read_data()
#       3 _ , *fcol2 , _ = st.columns(3)
#       5 scol1 , scol2 = st.columns(2)
#
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:211, in make_cached_func_wrapper.<locals>.wrapper(*args, **kwargs)
#     209 @functools.wraps(info.func)
#     210 def wrapper(*args, **kwargs):
# --> 211     return cached_func(*args, **kwargs)
#
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:240, in CachedFunc.__call__(self, *args, **kwargs)
#     238 if self._info.show_spinner or isinstance(self._info.show_spinner, str):
#     239     with spinner(message):
# --> 240         return self._get_or_create_cached_value(args, kwargs)
#     241 else:
#     242     return self._get_or_create_cached_value(args, kwargs)
#
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:266, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs)
#     264     return self._handle_cache_hit(cached_result)
#     265 except CacheKeyNotFoundError:
# --> 266     return self._handle_cache_miss(cache, value_key, func_args, func_kwargs)
#
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:320, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     315 except CacheKeyNotFoundError:
#     316     # We acquired the lock before any other thread. Compute the value!
#     317     with self._info.cached_message_replay_ctx.calling_cached_function(
#     318         self._info.func, self._info.allow_widgets
#     319     ):
# --> 320         computed_value = self._info.func(*func_args, **func_kwargs)
#     322     # We've computed our value, and now we need to write it back to the cache
#     323     # along with any "replay messages" that were generated during value computation.
#     324     messages = self._info.cached_message_replay_ctx._most_recent_messages
#
# Cell In[2], line 3, in read_data()
#       1 @st.cache_data
#       2 def read_data():
# ----> 3     all_vecs = np.load("all_vecs.npy")
#       4     all_names = np.load("all_names.npy")
#       5     return all_vecs , all_names
#
# File c:\Users\AVNI AGARWAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'all_vecs.npy'

# %%
ch = scol1.button("Start / change")
fs = scol2.button("find similar")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ch = scol1.button("Start / change")
#       2 fs = scol2.button("find similar")
#
# NameError: name 'scol1' is not defined

# %%
if ch:
    random_name = names[np.random.randint(len(names))]
    fcol2.image(Image.open("./images/" + random_name))
    st.session_state["disp_img"] = random_name
    st.write(st.session_state["disp_img"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 if ch:
#       2     random_name = names[np.random.randint(len(names))]
#       3     fcol2.image(Image.open("./images/" + random_name))
#
# NameError: name 'ch' is not defined

# %%
if fs:
    c1 , c2 , c3 , c4 , c5 = st.columns(5)
    idx = int(np.argwhere(names == st.session_state["disp_img"]))
    target_vec = vecs[idx]
    fcol2.image(Image.open("./images/" + st.session_state["disp_img"]))
    top5 = cdist(target_vec[None , ...] , vecs).squeeze().argsort()[1:6]
    c1.image(Image.open("./images/" + names[top5[0]]))
    c2.image(Image.open("./images/" + names[top5[1]]))
    c3.image(Image.open("./images/" + names[top5[2]]))
    c4.image(Image.open("./images/" + names[top5[3]]))
    c5.image(Image.open("./images/" + names[top5[4]]))
